# %%
# !pip install torch torchvision matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.datasets import FashionMNIST

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %%
train_dataset = FashionMNIST('./data',
                             train=True,
                             download=True,
                             transform=transforms.ToTensor())

test_dataset = FashionMNIST('./data',
                            train=False,
                            download=True,
                            transform=transforms.ToTensor())
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 16.1MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 267kB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 5.04MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 8.55MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size

train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Thêm định nghĩa batch_size ở đây
batch_size = 64

train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.hidden_dims = hidden_dims

        # Các lớp Linear
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        # Các lớp Batch Normalization
        self.bn1 = nn.BatchNorm1d(hidden_dims)
        self.bn2 = nn.BatchNorm1d(hidden_dims)
        self.bn3 = nn.BatchNorm1d(hidden_dims)
        self.bn4 = nn.BatchNorm1d(hidden_dims)
        self.bn5 = nn.BatchNorm1d(hidden_dims)
        self.bn6 = nn.BatchNorm1d(hidden_dims)
        self.bn7 = nn.BatchNorm1d(hidden_dims)

        # Khởi tạo trọng số và bias
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, mean=0.0, std=0.05)
                nn.init.constant_(module.bias, 0.0)

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.layer1(x)
        x = self.bn1(x)
        x = nn.Sigmoid()(x)

        x = self.layer2(x)
        x = self.bn2(x)
        x = nn.Sigmoid()(x)

        x = self.layer3(x)
        x = self.bn3(x)
        x = nn.Sigmoid()(x)

        x = self.layer4(x)
        x = self.bn4(x)
        x = nn.Sigmoid()(x)

        x = self.layer5(x)
        x = self.bn5(x)
        x = nn.Sigmoid()(x)

        x = self.layer6(x)
        x = self.bn6(x)
        x = nn.Sigmoid()(x)

        x = self.layer7(x)
        x = self.bn7(x)
        x = nn.Sigmoid()(x)

        out = self.output(x)
        return out


# Khởi tạo các tham số mô hình
input_dims = 784       # Input: 28x28 ảnh => 784 pixel
hidden_dims = 128      # Số node ẩn
output_dims = 10       # 10 nhãn tương ứng với Fashion MNIST
lr = 1e-2              # Learning rate

# Khởi tạo mô hình, hàm mất mát và optimizer
model = MLP(input_dims=input_dims, hidden_dims=hidden_dims, output_dims=output_dims).to(device)
criterion = nn.CrossEntropyLoss()  # Hàm mất mát CrossEntropyLoss
optimizer = optim.SGD(model.parameters(), lr=lr)  # Optimizer SGD với learning rate 0.01

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    # Chế độ huấn luyện
    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    # Chế độ đánh giá
    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(val_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)

    # In kết quả sau mỗi epoch
    print(f"EPOCH {epoch + 1}/{epochs}, "
          f"Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, "
          f"Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}")
# Out:
# EPOCH 1/100, Train_Loss: 1.2209, Train_Acc: 0.7287, Validation Loss: 0.8134, Val_Acc: 0.7993
# EPOCH 2/100, Train_Loss: 0.6787, Train_Acc: 0.8156, Validation Loss: 0.5886, Val_Acc: 0.8327
# EPOCH 3/100, Train_Loss: 0.5415, Train_Acc: 0.8351, Validation Loss: 0.5107, Val_Acc: 0.8378
# EPOCH 4/100, Train_Loss: 0.4791, Train_Acc: 0.8471, Validation Loss: 0.4659, Val_Acc: 0.8490
# EPOCH 5/100, Train_Loss: 0.4423, Train_Acc: 0.8552, Validation Loss: 0.4393, Val_Acc: 0.8577
# EPOCH 6/100, Train_Loss: 0.4159, Train_Acc: 0.8621, Validation Loss: 0.4271, Val_Acc: 0.8538
# EPOCH 7/100, Train_Loss: 0.3954, Train_Acc: 0.8669, Validation Loss: 0.4061, Val_Acc: 0.8612
# EPOCH 8/100, Train_Loss: 0.3810, Train_Acc: 0.8700, Validation Loss: 0.3988, Val_Acc: 0.8618
# EPOCH 9/100, Train_Loss: 0.3673, Train_Acc: 0.8744, Validation Loss: 0.3968, Val_Acc: 0.8608
# EPOCH 10/100, Train_Loss: 0.3584, Train_Acc: 0.8771, Validation Loss: 0.3738, Val_Acc: 0.8663
# EPOCH 11/100, Train_Loss: 0.3449, Train_Acc: 0.8807, Validation Loss: 0.3796, Val_Acc: 0.8675
# EPOCH 12/100, Train_Loss: 0.3345, Train_Acc: 0.8833, Validation Loss: 0.3718, Val_Acc: 0.8657
# EPOCH 13/100, Train_Loss: 0.3274, Train_Acc: 0.8855, Validation Loss: 0.3599, Val_Acc: 0.8743
# EPOCH 14/100, Train_Loss: 0.3205, Train_Acc: 0.8875, Validation Loss: 0.3729, Val_Acc: 0.8702
# EPOCH 15/100, Train_Loss: 0.3133, Train_Acc: 0.8901, Validation Loss: 0.3588, Val_Acc: 0.8710
# EPOCH 16/100, Train_Loss: 0.3072, Train_Acc: 0.8918, Validation Loss: 0.3813, Val_Acc: 0.8617
# EPOCH 17/100, Train_Loss: 0.2997, Train_Acc: 0.8944, Validation Loss: 0.3730, Val_Acc: 0.8670
# EPOCH 18/100, Train_Loss: 0.2942, Train_Acc: 0.8964, Validation Loss: 0.3529, Val_Acc: 0.8743
# EPOCH 19/100, Train_Loss: 0.2882, Train_Acc: 0.8987, Validation Loss: 0.3688, Val_Acc: 0.8695
# EPOCH 20/100, Train_Loss: 0.2840, Train_Acc: 0.8999, Validation Loss: 0.3470, Val_Acc: 0.8755
# EPOCH 21/100, Train_Loss: 0.2763, Train_Acc: 0.9024, Validation Loss: 0.3357, Val_Acc: 0.8800
# EPOCH 22/100, Train_Loss: 0.2747, Train_Acc: 0.9037, Validation Loss: 0.3346, Val_Acc: 0.8818
# EPOCH 23/100, Train_Loss: 0.2697, Train_Acc: 0.9039, Validation Loss: 0.3698, Val_Acc: 0.8678
# EPOCH 24/100, Train_Loss: 0.2633, Train_Acc: 0.9061, Validation Loss: 0.3531, Val_Acc: 0.8768
# EPOCH 25/100, Train_Loss: 0.2591, Train_Acc: 0.9079, Validation Loss: 0.3581, Val_Acc: 0.8677
# EPOCH 26/100, Train_Loss: 0.2557, Train_Acc: 0.9094, Validation Loss: 0.3453, Val_Acc: 0.8783
# EPOCH 27/100, Train_Loss: 0.2511, Train_Acc: 0.9115, Validation Loss: 0.3438, Val_Acc: 0.8795
# EPOCH 28/100, Train_Loss: 0.2468, Train_Acc: 0.9118, Validation Loss: 0.3351, Val_Acc: 0.8778
# EPOCH 29/100, Train_Loss: 0.2429, Train_Acc: 0.9131, Validation Loss: 0.3177, Val_Acc: 0.8853
# EPOCH 30/100, Train_Loss: 0.2399, Train_Acc: 0.9143, Validation Loss: 0.3261, Val_Acc: 0.8843
# EPOCH 31/100, Train_Loss: 0.2351, Train_Acc: 0.9167, Validation Loss: 0.3209, Val_Acc: 0.8872
# EPOCH 32/100, Train_Loss: 0.2293, Train_Acc: 0.9186, Validation Loss: 0.3251, Val_Acc: 0.8818
# EPOCH 33/100, Train_Loss: 0.2269, Train_Acc: 0.9189, Validation Loss: 0.3392, Val_Acc: 0.8813
# EPOCH 34/100, Train_Loss: 0.2246, Train_Acc: 0.9195, Validation Loss: 0.3246, Val_Acc: 0.8867
# EPOCH 35/100, Train_Loss: 0.2220, Train_Acc: 0.9214, Validation Loss: 0.3237, Val_Acc: 0.8810
# EPOCH 36/100, Train_Loss: 0.2180, Train_Acc: 0.9221, Validation Loss: 0.3514, Val_Acc: 0.8757
# EPOCH 37/100, Train_Loss: 0.2144, Train_Acc: 0.9239, Validation Loss: 0.3340, Val_Acc: 0.8867
# EPOCH 38/100, Train_Loss: 0.2110, Train_Acc: 0.9252, Validation Loss: 0.3317, Val_Acc: 0.8772
# EPOCH 39/100, Train_Loss: 0.2106, Train_Acc: 0.9257, Validation Loss: 0.3430, Val_Acc: 0.8775
# EPOCH 40/100, Train_Loss: 0.2054, Train_Acc: 0.9265, Validation Loss: 0.3366, Val_Acc: 0.8798
# EPOCH 41/100, Train_Loss: 0.1992, Train_Acc: 0.9291, Validation Loss: 0.3422, Val_Acc: 0.8828
# EPOCH 42/100, Train_Loss: 0.1990, Train_Acc: 0.9295, Validation Loss: 0.3347, Val_Acc: 0.8810
# EPOCH 43/100, Train_Loss: 0.1943, Train_Acc: 0.9316, Validation Loss: 0.3346, Val_Acc: 0.8807
# EPOCH 44/100, Train_Loss: 0.1924, Train_Acc: 0.9305, Validation Loss: 0.3244, Val_Acc: 0.8848
# EPOCH 45/100, Train_Loss: 0.1880, Train_Acc: 0.9336, Validation Loss: 0.3423, Val_Acc: 0.8785
# EPOCH 46/100, Train_Loss: 0.1859, Train_Acc: 0.9338, Validation Loss: 0.3302, Val_Acc: 0.8798
# EPOCH 47/100, Train_Loss: 0.1843, Train_Acc: 0.9340, Validation Loss: 0.3217, Val_Acc: 0.8897
# EPOCH 48/100, Train_Loss: 0.1818, Train_Acc: 0.9338, Validation Loss: 0.3414, Val_Acc: 0.8815
# EPOCH 49/100, Train_Loss: 0.1790, Train_Acc: 0.9363, Validation Loss: 0.3632, Val_Acc: 0.8747
# EPOCH 50/100, Train_Loss: 0.1781, Train_Acc: 0.9365, Validation Loss: 0.3312, Val_Acc: 0.8868
# EPOCH 51/100, Train_Loss: 0.1740, Train_Acc: 0.9385, Validation Loss: 0.3528, Val_Acc: 0.8820
# EPOCH 52/100, Train_Loss: 0.1693, Train_Acc: 0.9394, Validation Loss: 0.3508, Val_Acc: 0.8763
# EPOCH 53/100, Train_Loss: 0.1688, Train_Acc: 0.9395, Validation Loss: 0.3484, Val_Acc: 0.8785
# EPOCH 54/100, Train_Loss: 0.1660, Train_Acc: 0.9409, Validation Loss: 0.3335, Val_Acc: 0.8875
# EPOCH 55/100, Train_Loss: 0.1632, Train_Acc: 0.9428, Validation Loss: 0.3725, Val_Acc: 0.8680
# EPOCH 56/100, Train_Loss: 0.1614, Train_Acc: 0.9436, Validation Loss: 0.3465, Val_Acc: 0.8835
# EPOCH 57/100, Train_Loss: 0.1590, Train_Acc: 0.9432, Validation Loss: 0.3611, Val_Acc: 0.8750
# EPOCH 58/100, Train_Loss: 0.1592, Train_Acc: 0.9434, Validation Loss: 0.3573, Val_Acc: 0.8783
# EPOCH 59/100, Train_Loss: 0.1540, Train_Acc: 0.9450, Validation Loss: 0.3475, Val_Acc: 0.8828
# EPOCH 60/100, Train_Loss: 0.1502, Train_Acc: 0.9461, Validation Loss: 0.3463, Val_Acc: 0.8833
# EPOCH 61/100, Train_Loss: 0.1491, Train_Acc: 0.9456, Validation Loss: 0.3400, Val_Acc: 0.8843
# EPOCH 62/100, Train_Loss: 0.1454, Train_Acc: 0.9495, Validation Loss: 0.3468, Val_Acc: 0.8848
# EPOCH 63/100, Train_Loss: 0.1453, Train_Acc: 0.9489, Validation Loss: 0.3364, Val_Acc: 0.8873
# EPOCH 64/100, Train_Loss: 0.1436, Train_Acc: 0.9493, Validation Loss: 0.3562, Val_Acc: 0.8825
# EPOCH 65/100, Train_Loss: 0.1420, Train_Acc: 0.9498, Validation Loss: 0.3513, Val_Acc: 0.8808
# EPOCH 66/100, Train_Loss: 0.1387, Train_Acc: 0.9509, Validation Loss: 0.3864, Val_Acc: 0.8755
# EPOCH 67/100, Train_Loss: 0.1376, Train_Acc: 0.9513, Validation Loss: 0.3559, Val_Acc: 0.8813
# EPOCH 68/100, Train_Loss: 0.1336, Train_Acc: 0.9529, Validation Loss: 0.3559, Val_Acc: 0.8843
# EPOCH 69/100, Train_Loss: 0.1313, Train_Acc: 0.9540, Validation Loss: 0.3763, Val_Acc: 0.8792
# EPOCH 70/100, Train_Loss: 0.1303, Train_Acc: 0.9547, Validation Loss: 0.3603, Val_Acc: 0.8790
# EPOCH 71/100, Train_Loss: 0.1288, Train_Acc: 0.9554, Validation Loss: 0.3832, Val_Acc: 0.8763
# EPOCH 72/100, Train_Loss: 0.1270, Train_Acc: 0.9558, Validation Loss: 0.3523, Val_Acc: 0.8830
# EPOCH 73/100, Train_Loss: 0.1234, Train_Acc: 0.9571, Validation Loss: 0.3872, Val_Acc: 0.8785
# EPOCH 74/100, Train_Loss: 0.1264, Train_Acc: 0.9556, Validation Loss: 0.3484, Val_Acc: 0.8850
# EPOCH 75/100, Train_Loss: 0.1223, Train_Acc: 0.9572, Validation Loss: 0.3730, Val_Acc: 0.8817
# EPOCH 76/100, Train_Loss: 0.1168, Train_Acc: 0.9597, Validation Loss: 0.3490, Val_Acc: 0.8895
# EPOCH 77/100, Train_Loss: 0.1155, Train_Acc: 0.9588, Validation Loss: 0.3987, Val_Acc: 0.8778
# EPOCH 78/100, Train_Loss: 0.1158, Train_Acc: 0.9597, Validation Loss: 0.3819, Val_Acc: 0.8790
# EPOCH 79/100, Train_Loss: 0.1121, Train_Acc: 0.9612, Validation Loss: 0.3683, Val_Acc: 0.8795
# EPOCH 80/100, Train_Loss: 0.1109, Train_Acc: 0.9614, Validation Loss: 0.4049, Val_Acc: 0.8787
# EPOCH 81/100, Train_Loss: 0.1098, Train_Acc: 0.9618, Validation Loss: 0.3859, Val_Acc: 0.8763
# EPOCH 82/100, Train_Loss: 0.1088, Train_Acc: 0.9626, Validation Loss: 0.3852, Val_Acc: 0.8800
# EPOCH 83/100, Train_Loss: 0.1069, Train_Acc: 0.9623, Validation Loss: 0.3843, Val_Acc: 0.8783
# EPOCH 84/100, Train_Loss: 0.1055, Train_Acc: 0.9629, Validation Loss: 0.4397, Val_Acc: 0.8735
# EPOCH 85/100, Train_Loss: 0.1041, Train_Acc: 0.9645, Validation Loss: 0.3850, Val_Acc: 0.8775
# EPOCH 86/100, Train_Loss: 0.1019, Train_Acc: 0.9655, Validation Loss: 0.3813, Val_Acc: 0.8820
# EPOCH 87/100, Train_Loss: 0.1026, Train_Acc: 0.9647, Validation Loss: 0.4113, Val_Acc: 0.8765
# EPOCH 88/100, Train_Loss: 0.1002, Train_Acc: 0.9651, Validation Loss: 0.3860, Val_Acc: 0.8865
# EPOCH 89/100, Train_Loss: 0.0993, Train_Acc: 0.9649, Validation Loss: 0.4339, Val_Acc: 0.8692
# EPOCH 90/100, Train_Loss: 0.0995, Train_Acc: 0.9654, Validation Loss: 0.4637, Val_Acc: 0.8677
# EPOCH 91/100, Train_Loss: 0.0935, Train_Acc: 0.9685, Validation Loss: 0.3833, Val_Acc: 0.8795
# EPOCH 92/100, Train_Loss: 0.0916, Train_Acc: 0.9685, Validation Loss: 0.4038, Val_Acc: 0.8797
# EPOCH 93/100, Train_Loss: 0.0926, Train_Acc: 0.9678, Validation Loss: 0.3984, Val_Acc: 0.8807
# EPOCH 94/100, Train_Loss: 0.0918, Train_Acc: 0.9681, Validation Loss: 0.4101, Val_Acc: 0.8820
# EPOCH 95/100, Train_Loss: 0.0893, Train_Acc: 0.9699, Validation Loss: 0.3883, Val_Acc: 0.8800
# EPOCH 96/100, Train_Loss: 0.0891, Train_Acc: 0.9699, Validation Loss: 0.4013, Val_Acc: 0.8805
# EPOCH 97/100, Train_Loss: 0.0866, Train_Acc: 0.9704, Validation Loss: 0.4545, Val_Acc: 0.8752
# EPOCH 98/100, Train_Loss: 0.0847, Train_Acc: 0.9709, Validation Loss: 0.4412, Val_Acc: 0.8713
# EPOCH 99/100, Train_Loss: 0.0831, Train_Acc: 0.9711, Validation Loss: 0.4044, Val_Acc: 0.8798
# EPOCH 100/100, Train_Loss: 0.0802, Train_Acc: 0.9726, Validation Loss: 0.4280, Val_Acc: 0.8763

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

# Vẽ Training Loss
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

# Vẽ Validation Loss
ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

# Vẽ Training Accuracy
ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

# Vẽ Validation Accuracy
ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
test_target = []
test_predict = []

# Đặt mô hình ở chế độ đánh giá
model.eval()
with torch.no_grad():
    for X_test, y_test in test_loader:
        X_test = X_test.to(device)
        y_test = y_test.to(device)
        outputs = model(X_test)

        # Lưu lại dự đoán và nhãn thực tế
        test_predict.append(outputs.cpu())
        test_target.append(y_test.cpu())

# Ghép kết quả từ các batch thành một tensor duy nhất
test_predict = torch.cat(test_predict)
test_target = torch.cat(test_target)

# Tính toán độ chính xác
test_acc = (torch.argmax(test_predict, 1) == test_target).sum().item() / len(test_target)

# In kết quả
print('Evaluation on test set:')
print(f'Accuracy: {test_acc:.4f}')
# Out:
# Evaluation on test set:
# Accuracy: 0.8769
