# %%
# !pip install torch torchvision matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.datasets import FashionMNIST

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %%
train_dataset = FashionMNIST('./data',
                             train=True,
                             download=True,
                             transform=transforms.ToTensor())

test_dataset = FashionMNIST('./data',
                            train=False,
                            download=True,
                            transform=transforms.ToTensor())
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 16.1MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 271kB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 4.99MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 8.54MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size

train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Thêm định nghĩa batch_size ở đây
batch_size = 64

train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        # Khởi tạo trọng số và bias
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, mean=0.0, std=0.05)
                nn.init.constant_(module.bias, 0.0)

    def forward(self, x):
        x = nn.Flatten()(x)

        # Block 1
        x = self.layer1(x)
        x = nn.Sigmoid()(x)
        skip = x  # Lưu skip connection từ layer1

        # Block 2
        x = self.layer2(x)
        x = nn.Sigmoid()(x)
        x = self.layer3(x)
        x = nn.Sigmoid()(x)
        x = skip + x  # Thêm skip connection từ layer1

        # Block 3
        x = self.layer4(x)
        x = nn.Sigmoid()(x)
        skip = x  # Lưu skip connection từ layer4

        # Block 4
        x = self.layer5(x)
        x = nn.Sigmoid()(x)
        x = self.layer6(x)
        x = nn.Sigmoid()(x)
        x = self.layer7(x)
        x = nn.Sigmoid()(x)
        x = skip + x  # Thêm skip connection từ layer4

        # Output layer
        out = self.output(x)
        return out


# Khởi tạo các tham số mô hình
input_dims = 784       # Input: 28x28 ảnh => 784 pixel
hidden_dims = 128      # Số node ẩn
output_dims = 10       # 10 nhãn tương ứng với Fashion MNIST
lr = 1e-2              # Learning rate

# Khởi tạo mô hình, hàm mất mát và optimizer
model = MLP(input_dims=input_dims, hidden_dims=hidden_dims, output_dims=output_dims).to(device)
criterion = nn.CrossEntropyLoss()  # Hàm mất mát CrossEntropyLoss
optimizer = optim.SGD(model.parameters(), lr=lr)  # Optimizer SGD với learning rate 0.01

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    # Chế độ huấn luyện
    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    # Chế độ đánh giá
    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(val_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)

    # In kết quả sau mỗi epoch
    print(f"EPOCH {epoch + 1}/{epochs}, "
          f"Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, "
          f"Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}")
# Out:
# EPOCH 1/100, Train_Loss: 2.2989, Train_Acc: 0.1199, Validation Loss: 2.2933, Val_Acc: 0.0895
# EPOCH 2/100, Train_Loss: 2.2653, Train_Acc: 0.1858, Validation Loss: 2.2374, Val_Acc: 0.3053
# EPOCH 3/100, Train_Loss: 2.1614, Train_Acc: 0.2854, Validation Loss: 2.0512, Val_Acc: 0.3388
# EPOCH 4/100, Train_Loss: 1.8887, Train_Acc: 0.3638, Validation Loss: 1.7471, Val_Acc: 0.4788
# EPOCH 5/100, Train_Loss: 1.6370, Train_Acc: 0.4490, Validation Loss: 1.5493, Val_Acc: 0.5015
# EPOCH 6/100, Train_Loss: 1.4507, Train_Acc: 0.5194, Validation Loss: 1.3760, Val_Acc: 0.5422
# EPOCH 7/100, Train_Loss: 1.2955, Train_Acc: 0.5677, Validation Loss: 1.2480, Val_Acc: 0.5658
# EPOCH 8/100, Train_Loss: 1.1841, Train_Acc: 0.5938, Validation Loss: 1.1572, Val_Acc: 0.5898
# EPOCH 9/100, Train_Loss: 1.1026, Train_Acc: 0.6124, Validation Loss: 1.0879, Val_Acc: 0.6013
# EPOCH 10/100, Train_Loss: 1.0409, Train_Acc: 0.6248, Validation Loss: 1.0297, Val_Acc: 0.6078
# EPOCH 11/100, Train_Loss: 0.9903, Train_Acc: 0.6367, Validation Loss: 0.9857, Val_Acc: 0.6468
# EPOCH 12/100, Train_Loss: 0.9463, Train_Acc: 0.6497, Validation Loss: 0.9437, Val_Acc: 0.6377
# EPOCH 13/100, Train_Loss: 0.9075, Train_Acc: 0.6652, Validation Loss: 0.9054, Val_Acc: 0.6630
# EPOCH 14/100, Train_Loss: 0.8720, Train_Acc: 0.6774, Validation Loss: 0.8753, Val_Acc: 0.6885
# EPOCH 15/100, Train_Loss: 0.8391, Train_Acc: 0.6915, Validation Loss: 0.8404, Val_Acc: 0.6708
# EPOCH 16/100, Train_Loss: 0.8080, Train_Acc: 0.7094, Validation Loss: 0.8098, Val_Acc: 0.7185
# EPOCH 17/100, Train_Loss: 0.7797, Train_Acc: 0.7204, Validation Loss: 0.7859, Val_Acc: 0.7222
# EPOCH 18/100, Train_Loss: 0.7535, Train_Acc: 0.7296, Validation Loss: 0.7588, Val_Acc: 0.7207
# EPOCH 19/100, Train_Loss: 0.7299, Train_Acc: 0.7353, Validation Loss: 0.7377, Val_Acc: 0.7263
# EPOCH 20/100, Train_Loss: 0.7091, Train_Acc: 0.7416, Validation Loss: 0.7150, Val_Acc: 0.7312
# EPOCH 21/100, Train_Loss: 0.6903, Train_Acc: 0.7464, Validation Loss: 0.6973, Val_Acc: 0.7412
# EPOCH 22/100, Train_Loss: 0.6747, Train_Acc: 0.7496, Validation Loss: 0.6833, Val_Acc: 0.7470
# EPOCH 23/100, Train_Loss: 0.6602, Train_Acc: 0.7530, Validation Loss: 0.6686, Val_Acc: 0.7502
# EPOCH 24/100, Train_Loss: 0.6473, Train_Acc: 0.7577, Validation Loss: 0.6623, Val_Acc: 0.7463
# EPOCH 25/100, Train_Loss: 0.6361, Train_Acc: 0.7611, Validation Loss: 0.6450, Val_Acc: 0.7560
# EPOCH 26/100, Train_Loss: 0.6260, Train_Acc: 0.7643, Validation Loss: 0.6356, Val_Acc: 0.7567
# EPOCH 27/100, Train_Loss: 0.6161, Train_Acc: 0.7681, Validation Loss: 0.6278, Val_Acc: 0.7527
# EPOCH 28/100, Train_Loss: 0.6074, Train_Acc: 0.7716, Validation Loss: 0.6155, Val_Acc: 0.7660
# EPOCH 29/100, Train_Loss: 0.5986, Train_Acc: 0.7766, Validation Loss: 0.6063, Val_Acc: 0.7702
# EPOCH 30/100, Train_Loss: 0.5911, Train_Acc: 0.7796, Validation Loss: 0.6014, Val_Acc: 0.7732
# EPOCH 31/100, Train_Loss: 0.5834, Train_Acc: 0.7827, Validation Loss: 0.5939, Val_Acc: 0.7763
# EPOCH 32/100, Train_Loss: 0.5766, Train_Acc: 0.7882, Validation Loss: 0.5877, Val_Acc: 0.7842
# EPOCH 33/100, Train_Loss: 0.5694, Train_Acc: 0.7909, Validation Loss: 0.5832, Val_Acc: 0.7857
# EPOCH 34/100, Train_Loss: 0.5634, Train_Acc: 0.7944, Validation Loss: 0.5750, Val_Acc: 0.7870
# EPOCH 35/100, Train_Loss: 0.5577, Train_Acc: 0.7976, Validation Loss: 0.5667, Val_Acc: 0.7925
# EPOCH 36/100, Train_Loss: 0.5516, Train_Acc: 0.8002, Validation Loss: 0.5645, Val_Acc: 0.7917
# EPOCH 37/100, Train_Loss: 0.5462, Train_Acc: 0.8029, Validation Loss: 0.5583, Val_Acc: 0.7972
# EPOCH 38/100, Train_Loss: 0.5409, Train_Acc: 0.8066, Validation Loss: 0.5524, Val_Acc: 0.8028
# EPOCH 39/100, Train_Loss: 0.5361, Train_Acc: 0.8071, Validation Loss: 0.5469, Val_Acc: 0.8053
# EPOCH 40/100, Train_Loss: 0.5316, Train_Acc: 0.8104, Validation Loss: 0.5424, Val_Acc: 0.8082
# EPOCH 41/100, Train_Loss: 0.5270, Train_Acc: 0.8123, Validation Loss: 0.5405, Val_Acc: 0.8075
# EPOCH 42/100, Train_Loss: 0.5228, Train_Acc: 0.8141, Validation Loss: 0.5352, Val_Acc: 0.8123
# EPOCH 43/100, Train_Loss: 0.5188, Train_Acc: 0.8165, Validation Loss: 0.5350, Val_Acc: 0.8088
# EPOCH 44/100, Train_Loss: 0.5148, Train_Acc: 0.8166, Validation Loss: 0.5311, Val_Acc: 0.8125
# EPOCH 45/100, Train_Loss: 0.5109, Train_Acc: 0.8189, Validation Loss: 0.5266, Val_Acc: 0.8123
# EPOCH 46/100, Train_Loss: 0.5076, Train_Acc: 0.8206, Validation Loss: 0.5200, Val_Acc: 0.8168
# EPOCH 47/100, Train_Loss: 0.5040, Train_Acc: 0.8218, Validation Loss: 0.5167, Val_Acc: 0.8162
# EPOCH 48/100, Train_Loss: 0.5001, Train_Acc: 0.8228, Validation Loss: 0.5138, Val_Acc: 0.8190
# EPOCH 49/100, Train_Loss: 0.4968, Train_Acc: 0.8247, Validation Loss: 0.5116, Val_Acc: 0.8195
# EPOCH 50/100, Train_Loss: 0.4939, Train_Acc: 0.8251, Validation Loss: 0.5093, Val_Acc: 0.8188
# EPOCH 51/100, Train_Loss: 0.4906, Train_Acc: 0.8259, Validation Loss: 0.5061, Val_Acc: 0.8197
# EPOCH 52/100, Train_Loss: 0.4875, Train_Acc: 0.8269, Validation Loss: 0.5051, Val_Acc: 0.8217
# EPOCH 53/100, Train_Loss: 0.4845, Train_Acc: 0.8283, Validation Loss: 0.5011, Val_Acc: 0.8217
# EPOCH 54/100, Train_Loss: 0.4818, Train_Acc: 0.8291, Validation Loss: 0.4991, Val_Acc: 0.8218
# EPOCH 55/100, Train_Loss: 0.4790, Train_Acc: 0.8299, Validation Loss: 0.4969, Val_Acc: 0.8230
# EPOCH 56/100, Train_Loss: 0.4762, Train_Acc: 0.8311, Validation Loss: 0.4956, Val_Acc: 0.8260
# EPOCH 57/100, Train_Loss: 0.4734, Train_Acc: 0.8322, Validation Loss: 0.4924, Val_Acc: 0.8248
# EPOCH 58/100, Train_Loss: 0.4710, Train_Acc: 0.8330, Validation Loss: 0.4888, Val_Acc: 0.8292
# EPOCH 59/100, Train_Loss: 0.4684, Train_Acc: 0.8338, Validation Loss: 0.4860, Val_Acc: 0.8283
# EPOCH 60/100, Train_Loss: 0.4655, Train_Acc: 0.8345, Validation Loss: 0.4901, Val_Acc: 0.8228
# EPOCH 61/100, Train_Loss: 0.4631, Train_Acc: 0.8360, Validation Loss: 0.4828, Val_Acc: 0.8292
# EPOCH 62/100, Train_Loss: 0.4607, Train_Acc: 0.8364, Validation Loss: 0.4836, Val_Acc: 0.8273
# EPOCH 63/100, Train_Loss: 0.4582, Train_Acc: 0.8377, Validation Loss: 0.4837, Val_Acc: 0.8262
# EPOCH 64/100, Train_Loss: 0.4562, Train_Acc: 0.8390, Validation Loss: 0.4761, Val_Acc: 0.8302
# EPOCH 65/100, Train_Loss: 0.4535, Train_Acc: 0.8402, Validation Loss: 0.4736, Val_Acc: 0.8315
# EPOCH 66/100, Train_Loss: 0.4515, Train_Acc: 0.8396, Validation Loss: 0.4738, Val_Acc: 0.8307
# EPOCH 67/100, Train_Loss: 0.4494, Train_Acc: 0.8404, Validation Loss: 0.4733, Val_Acc: 0.8298
# EPOCH 68/100, Train_Loss: 0.4474, Train_Acc: 0.8411, Validation Loss: 0.4689, Val_Acc: 0.8323
# EPOCH 69/100, Train_Loss: 0.4450, Train_Acc: 0.8423, Validation Loss: 0.4703, Val_Acc: 0.8317
# EPOCH 70/100, Train_Loss: 0.4432, Train_Acc: 0.8427, Validation Loss: 0.4671, Val_Acc: 0.8307
# EPOCH 71/100, Train_Loss: 0.4410, Train_Acc: 0.8434, Validation Loss: 0.4645, Val_Acc: 0.8317
# EPOCH 72/100, Train_Loss: 0.4390, Train_Acc: 0.8446, Validation Loss: 0.4614, Val_Acc: 0.8328
# EPOCH 73/100, Train_Loss: 0.4374, Train_Acc: 0.8440, Validation Loss: 0.4600, Val_Acc: 0.8353
# EPOCH 74/100, Train_Loss: 0.4355, Train_Acc: 0.8458, Validation Loss: 0.4598, Val_Acc: 0.8323
# EPOCH 75/100, Train_Loss: 0.4335, Train_Acc: 0.8456, Validation Loss: 0.4560, Val_Acc: 0.8327
# EPOCH 76/100, Train_Loss: 0.4316, Train_Acc: 0.8463, Validation Loss: 0.4563, Val_Acc: 0.8360
# EPOCH 77/100, Train_Loss: 0.4301, Train_Acc: 0.8471, Validation Loss: 0.4543, Val_Acc: 0.8352
# EPOCH 78/100, Train_Loss: 0.4282, Train_Acc: 0.8479, Validation Loss: 0.4524, Val_Acc: 0.8355
# EPOCH 79/100, Train_Loss: 0.4262, Train_Acc: 0.8484, Validation Loss: 0.4530, Val_Acc: 0.8357
# EPOCH 80/100, Train_Loss: 0.4249, Train_Acc: 0.8486, Validation Loss: 0.4491, Val_Acc: 0.8360
# EPOCH 81/100, Train_Loss: 0.4234, Train_Acc: 0.8493, Validation Loss: 0.4480, Val_Acc: 0.8387
# EPOCH 82/100, Train_Loss: 0.4218, Train_Acc: 0.8505, Validation Loss: 0.4480, Val_Acc: 0.8377
# EPOCH 83/100, Train_Loss: 0.4203, Train_Acc: 0.8497, Validation Loss: 0.4488, Val_Acc: 0.8373
# EPOCH 84/100, Train_Loss: 0.4185, Train_Acc: 0.8510, Validation Loss: 0.4443, Val_Acc: 0.8415
# EPOCH 85/100, Train_Loss: 0.4171, Train_Acc: 0.8515, Validation Loss: 0.4451, Val_Acc: 0.8382
# EPOCH 86/100, Train_Loss: 0.4153, Train_Acc: 0.8523, Validation Loss: 0.4444, Val_Acc: 0.8403
# EPOCH 87/100, Train_Loss: 0.4140, Train_Acc: 0.8524, Validation Loss: 0.4416, Val_Acc: 0.8415
# EPOCH 88/100, Train_Loss: 0.4129, Train_Acc: 0.8525, Validation Loss: 0.4415, Val_Acc: 0.8410
# EPOCH 89/100, Train_Loss: 0.4111, Train_Acc: 0.8532, Validation Loss: 0.4375, Val_Acc: 0.8438
# EPOCH 90/100, Train_Loss: 0.4102, Train_Acc: 0.8538, Validation Loss: 0.4409, Val_Acc: 0.8405
# EPOCH 91/100, Train_Loss: 0.4082, Train_Acc: 0.8546, Validation Loss: 0.4402, Val_Acc: 0.8423
# EPOCH 92/100, Train_Loss: 0.4071, Train_Acc: 0.8541, Validation Loss: 0.4334, Val_Acc: 0.8422
# EPOCH 93/100, Train_Loss: 0.4055, Train_Acc: 0.8549, Validation Loss: 0.4330, Val_Acc: 0.8435
# EPOCH 94/100, Train_Loss: 0.4041, Train_Acc: 0.8555, Validation Loss: 0.4352, Val_Acc: 0.8442
# EPOCH 95/100, Train_Loss: 0.4032, Train_Acc: 0.8563, Validation Loss: 0.4327, Val_Acc: 0.8442
# EPOCH 96/100, Train_Loss: 0.4015, Train_Acc: 0.8569, Validation Loss: 0.4308, Val_Acc: 0.8440
# EPOCH 97/100, Train_Loss: 0.4003, Train_Acc: 0.8577, Validation Loss: 0.4340, Val_Acc: 0.8447
# EPOCH 98/100, Train_Loss: 0.3989, Train_Acc: 0.8581, Validation Loss: 0.4347, Val_Acc: 0.8453
# EPOCH 99/100, Train_Loss: 0.3979, Train_Acc: 0.8589, Validation Loss: 0.4276, Val_Acc: 0.8473
# EPOCH 100/100, Train_Loss: 0.3967, Train_Acc: 0.8580, Validation Loss: 0.4246, Val_Acc: 0.8463

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

# Vẽ Training Loss
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

# Vẽ Validation Loss
ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

# Vẽ Training Accuracy
ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

# Vẽ Validation Accuracy
ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
test_target = []
test_predict = []

# Đặt mô hình ở chế độ đánh giá
model.eval()
with torch.no_grad():
    for X_test, y_test in test_loader:
        X_test = X_test.to(device)
        y_test = y_test.to(device)
        outputs = model(X_test)

        # Lưu lại dự đoán và nhãn thực tế
        test_predict.append(outputs.cpu())
        test_target.append(y_test.cpu())

# Ghép kết quả từ các batch thành một tensor duy nhất
test_predict = torch.cat(test_predict)
test_target = torch.cat(test_target)

# Tính toán độ chính xác
test_acc = (torch.argmax(test_predict, 1) == test_target).sum().item() / len(test_target)

# In kết quả
print('Evaluation on test set:')
print(f'Accuracy: {test_acc:.4f}')
# Out:
# Evaluation on test set:
# Accuracy: 0.8422
