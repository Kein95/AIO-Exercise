# %%
# !pip install torch torchvision matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.datasets import FashionMNIST

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %%
train_dataset = FashionMNIST('./data',
                             train=True,
                             download=True,
                             transform=transforms.ToTensor())

test_dataset = FashionMNIST('./data',
                            train=False,
                            download=True,
                            transform=transforms.ToTensor())
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 15.9MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 274kB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 4.98MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 7.52MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size

train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# Thêm định nghĩa batch_size ở đây
batch_size = 64

train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %%
class MyNormalization(nn.Module):
    def __init__(self):
        super(MyNormalization, self).__init__()

    def forward(self, x):
        mean = torch.mean(x)
        std = torch.std(x)
        return (x - mean) / (std + 1e-6)  # Thêm epsilon nhỏ để tránh chia cho 0

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.hidden_dims = hidden_dims

        # Các lớp Linear
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        # Các lớp MyNormalization thay thế BatchNorm1d
        self.norm1 = MyNormalization()
        self.norm2 = MyNormalization()
        self.norm3 = MyNormalization()
        self.norm4 = MyNormalization()
        self.norm5 = MyNormalization()
        self.norm6 = MyNormalization()
        self.norm7 = MyNormalization()

        # Khởi tạo trọng số và bias
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, mean=0.0, std=0.05)
                nn.init.constant_(module.bias, 0.0)

    def forward(self, x):
        x = nn.Flatten()(x)

        x = self.layer1(x)
        x = self.norm1(x)
        x = nn.Sigmoid()(x)

        x = self.layer2(x)
        x = self.norm2(x)
        x = nn.Sigmoid()(x)

        x = self.layer3(x)
        x = self.norm3(x)
        x = nn.Sigmoid()(x)

        x = self.layer4(x)
        x = self.norm4(x)
        x = nn.Sigmoid()(x)

        x = self.layer5(x)
        x = self.norm5(x)
        x = nn.Sigmoid()(x)

        x = self.layer6(x)
        x = self.norm6(x)
        x = nn.Sigmoid()(x)

        x = self.layer7(x)
        x = self.norm7(x)
        x = nn.Sigmoid()(x)

        out = self.output(x)
        return out


# Khởi tạo các tham số mô hình
input_dims = 784       # Input: 28x28 ảnh => 784 pixel
hidden_dims = 128      # Số node ẩn
output_dims = 10       # 10 nhãn tương ứng với Fashion MNIST
lr = 1e-2              # Learning rate

# Khởi tạo mô hình, hàm mất mát và optimizer
model = MLP(input_dims=input_dims, hidden_dims=hidden_dims, output_dims=output_dims).to(device)
criterion = nn.CrossEntropyLoss()  # Hàm mất mát CrossEntropyLoss
optimizer = optim.SGD(model.parameters(), lr=lr)  # Optimizer SGD với learning rate 0.01

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    # Chế độ huấn luyện
    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    # Chế độ đánh giá
    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(val_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)

    # In kết quả sau mỗi epoch
    print(f"EPOCH {epoch + 1}/{epochs}, "
          f"Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, "
          f"Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}")
# Out:
# EPOCH 1/100, Train_Loss: 2.3048, Train_Acc: 0.0975, Validation Loss: 2.3036, Val_Acc: 0.0937
# EPOCH 2/100, Train_Loss: 2.3042, Train_Acc: 0.0996, Validation Loss: 2.3047, Val_Acc: 0.1018
# EPOCH 3/100, Train_Loss: 2.3043, Train_Acc: 0.0987, Validation Loss: 2.3032, Val_Acc: 0.1022
# EPOCH 4/100, Train_Loss: 2.3042, Train_Acc: 0.0989, Validation Loss: 2.3038, Val_Acc: 0.0937
# EPOCH 5/100, Train_Loss: 2.3038, Train_Acc: 0.1003, Validation Loss: 2.3033, Val_Acc: 0.0997
# EPOCH 6/100, Train_Loss: 2.3039, Train_Acc: 0.1003, Validation Loss: 2.3049, Val_Acc: 0.1020
# EPOCH 7/100, Train_Loss: 2.3040, Train_Acc: 0.0989, Validation Loss: 2.3031, Val_Acc: 0.1020
# EPOCH 8/100, Train_Loss: 2.3034, Train_Acc: 0.1014, Validation Loss: 2.3029, Val_Acc: 0.1020
# EPOCH 9/100, Train_Loss: 2.3026, Train_Acc: 0.1046, Validation Loss: 2.3036, Val_Acc: 0.0937
# EPOCH 10/100, Train_Loss: 2.1529, Train_Acc: 0.2113, Validation Loss: 1.5715, Val_Acc: 0.5522
# EPOCH 11/100, Train_Loss: 1.1251, Train_Acc: 0.6900, Validation Loss: 0.8959, Val_Acc: 0.7270
# EPOCH 12/100, Train_Loss: 0.7581, Train_Acc: 0.7666, Validation Loss: 0.6462, Val_Acc: 0.7975
# EPOCH 13/100, Train_Loss: 0.6208, Train_Acc: 0.8028, Validation Loss: 0.5956, Val_Acc: 0.8105
# EPOCH 14/100, Train_Loss: 0.5553, Train_Acc: 0.8181, Validation Loss: 0.5964, Val_Acc: 0.7990
# EPOCH 15/100, Train_Loss: 0.5170, Train_Acc: 0.8283, Validation Loss: 0.5658, Val_Acc: 0.8158
# EPOCH 16/100, Train_Loss: 0.4898, Train_Acc: 0.8343, Validation Loss: 0.5320, Val_Acc: 0.8227
# EPOCH 17/100, Train_Loss: 0.4664, Train_Acc: 0.8418, Validation Loss: 0.4957, Val_Acc: 0.8327
# EPOCH 18/100, Train_Loss: 0.4542, Train_Acc: 0.8447, Validation Loss: 0.4648, Val_Acc: 0.8357
# EPOCH 19/100, Train_Loss: 0.4396, Train_Acc: 0.8501, Validation Loss: 0.5117, Val_Acc: 0.8295
# EPOCH 20/100, Train_Loss: 0.4304, Train_Acc: 0.8510, Validation Loss: 0.4549, Val_Acc: 0.8438
# EPOCH 21/100, Train_Loss: 0.4188, Train_Acc: 0.8544, Validation Loss: 0.4872, Val_Acc: 0.8182
# EPOCH 22/100, Train_Loss: 0.4134, Train_Acc: 0.8563, Validation Loss: 0.5033, Val_Acc: 0.8140
# EPOCH 23/100, Train_Loss: 0.4043, Train_Acc: 0.8578, Validation Loss: 0.5279, Val_Acc: 0.8208
# EPOCH 24/100, Train_Loss: 0.3996, Train_Acc: 0.8597, Validation Loss: 0.4161, Val_Acc: 0.8572
# EPOCH 25/100, Train_Loss: 0.3913, Train_Acc: 0.8626, Validation Loss: 0.4128, Val_Acc: 0.8582
# EPOCH 26/100, Train_Loss: 0.3872, Train_Acc: 0.8641, Validation Loss: 0.4074, Val_Acc: 0.8588
# EPOCH 27/100, Train_Loss: 0.3879, Train_Acc: 0.8641, Validation Loss: 0.3828, Val_Acc: 0.8617
# EPOCH 28/100, Train_Loss: 0.3762, Train_Acc: 0.8677, Validation Loss: 0.4168, Val_Acc: 0.8535
# EPOCH 29/100, Train_Loss: 0.3698, Train_Acc: 0.8684, Validation Loss: 0.4221, Val_Acc: 0.8443
# EPOCH 30/100, Train_Loss: 0.3742, Train_Acc: 0.8664, Validation Loss: 0.3888, Val_Acc: 0.8648
# EPOCH 31/100, Train_Loss: 0.3629, Train_Acc: 0.8719, Validation Loss: 0.3815, Val_Acc: 0.8632
# EPOCH 32/100, Train_Loss: 0.3568, Train_Acc: 0.8741, Validation Loss: 0.4005, Val_Acc: 0.8577
# EPOCH 33/100, Train_Loss: 0.3561, Train_Acc: 0.8736, Validation Loss: 0.4251, Val_Acc: 0.8475
# EPOCH 34/100, Train_Loss: 0.3515, Train_Acc: 0.8749, Validation Loss: 0.4005, Val_Acc: 0.8580
# EPOCH 35/100, Train_Loss: 0.3469, Train_Acc: 0.8767, Validation Loss: 0.4208, Val_Acc: 0.8533
# EPOCH 36/100, Train_Loss: 0.3433, Train_Acc: 0.8778, Validation Loss: 0.4089, Val_Acc: 0.8600
# EPOCH 37/100, Train_Loss: 0.3385, Train_Acc: 0.8788, Validation Loss: 0.4119, Val_Acc: 0.8498
# EPOCH 38/100, Train_Loss: 0.3385, Train_Acc: 0.8793, Validation Loss: 0.3908, Val_Acc: 0.8612
# EPOCH 39/100, Train_Loss: 0.3329, Train_Acc: 0.8810, Validation Loss: 0.3738, Val_Acc: 0.8635
# EPOCH 40/100, Train_Loss: 0.3315, Train_Acc: 0.8822, Validation Loss: 0.3646, Val_Acc: 0.8715
# EPOCH 41/100, Train_Loss: 0.3281, Train_Acc: 0.8842, Validation Loss: 0.3919, Val_Acc: 0.8603
# EPOCH 42/100, Train_Loss: 0.3269, Train_Acc: 0.8831, Validation Loss: 0.3544, Val_Acc: 0.8732
# EPOCH 43/100, Train_Loss: 0.3220, Train_Acc: 0.8841, Validation Loss: 0.3672, Val_Acc: 0.8697
# EPOCH 44/100, Train_Loss: 0.3208, Train_Acc: 0.8851, Validation Loss: 0.3651, Val_Acc: 0.8690
# EPOCH 45/100, Train_Loss: 0.3171, Train_Acc: 0.8859, Validation Loss: 0.4110, Val_Acc: 0.8472
# EPOCH 46/100, Train_Loss: 0.3223, Train_Acc: 0.8844, Validation Loss: 0.3616, Val_Acc: 0.8718
# EPOCH 47/100, Train_Loss: 0.3137, Train_Acc: 0.8857, Validation Loss: 0.3543, Val_Acc: 0.8767
# EPOCH 48/100, Train_Loss: 0.3096, Train_Acc: 0.8887, Validation Loss: 0.3712, Val_Acc: 0.8695
# EPOCH 49/100, Train_Loss: 0.3073, Train_Acc: 0.8896, Validation Loss: 0.3675, Val_Acc: 0.8737
# EPOCH 50/100, Train_Loss: 0.3057, Train_Acc: 0.8917, Validation Loss: 0.3616, Val_Acc: 0.8673
# EPOCH 51/100, Train_Loss: 0.3123, Train_Acc: 0.8884, Validation Loss: 0.3432, Val_Acc: 0.8777
# EPOCH 52/100, Train_Loss: 0.3002, Train_Acc: 0.8919, Validation Loss: 0.3574, Val_Acc: 0.8727
# EPOCH 53/100, Train_Loss: 0.2996, Train_Acc: 0.8925, Validation Loss: 0.3625, Val_Acc: 0.8690
# EPOCH 54/100, Train_Loss: 0.2960, Train_Acc: 0.8928, Validation Loss: 0.3533, Val_Acc: 0.8747
# EPOCH 55/100, Train_Loss: 0.2921, Train_Acc: 0.8953, Validation Loss: 0.3485, Val_Acc: 0.8757
# EPOCH 56/100, Train_Loss: 0.2914, Train_Acc: 0.8947, Validation Loss: 0.3825, Val_Acc: 0.8675
# EPOCH 57/100, Train_Loss: 0.2905, Train_Acc: 0.8960, Validation Loss: 0.3410, Val_Acc: 0.8802
# EPOCH 58/100, Train_Loss: 0.3068, Train_Acc: 0.8914, Validation Loss: 0.4033, Val_Acc: 0.8570
# EPOCH 59/100, Train_Loss: 0.2850, Train_Acc: 0.8978, Validation Loss: 0.4151, Val_Acc: 0.8462
# EPOCH 60/100, Train_Loss: 0.2961, Train_Acc: 0.8951, Validation Loss: 0.3438, Val_Acc: 0.8772
# EPOCH 61/100, Train_Loss: 0.2928, Train_Acc: 0.8945, Validation Loss: 0.3728, Val_Acc: 0.8628
# EPOCH 62/100, Train_Loss: 0.2801, Train_Acc: 0.8993, Validation Loss: 0.3415, Val_Acc: 0.8777
# EPOCH 63/100, Train_Loss: 0.2781, Train_Acc: 0.8999, Validation Loss: 0.3999, Val_Acc: 0.8510
# EPOCH 64/100, Train_Loss: 0.2768, Train_Acc: 0.8997, Validation Loss: 0.3465, Val_Acc: 0.8778
# EPOCH 65/100, Train_Loss: 0.2738, Train_Acc: 0.9020, Validation Loss: 0.4256, Val_Acc: 0.8415
# EPOCH 66/100, Train_Loss: 0.2741, Train_Acc: 0.9010, Validation Loss: 0.3750, Val_Acc: 0.8670
# EPOCH 67/100, Train_Loss: 0.2726, Train_Acc: 0.9018, Validation Loss: 0.3477, Val_Acc: 0.8730
# EPOCH 68/100, Train_Loss: 0.2711, Train_Acc: 0.9033, Validation Loss: 0.3503, Val_Acc: 0.8747
# EPOCH 69/100, Train_Loss: 0.2820, Train_Acc: 0.9001, Validation Loss: 0.3685, Val_Acc: 0.8720
# EPOCH 70/100, Train_Loss: 0.2656, Train_Acc: 0.9037, Validation Loss: 0.4068, Val_Acc: 0.8517
# EPOCH 71/100, Train_Loss: 0.2669, Train_Acc: 0.9033, Validation Loss: 0.4527, Val_Acc: 0.8368
# EPOCH 72/100, Train_Loss: 0.2620, Train_Acc: 0.9061, Validation Loss: 0.3506, Val_Acc: 0.8762
# EPOCH 73/100, Train_Loss: 0.2599, Train_Acc: 0.9055, Validation Loss: 0.3593, Val_Acc: 0.8712
# EPOCH 74/100, Train_Loss: 0.2625, Train_Acc: 0.9069, Validation Loss: 0.3680, Val_Acc: 0.8698
# EPOCH 75/100, Train_Loss: 0.2585, Train_Acc: 0.9076, Validation Loss: 0.4249, Val_Acc: 0.8515
# EPOCH 76/100, Train_Loss: 0.2761, Train_Acc: 0.9041, Validation Loss: 0.3507, Val_Acc: 0.8763
# EPOCH 77/100, Train_Loss: 0.2563, Train_Acc: 0.9066, Validation Loss: 0.3781, Val_Acc: 0.8658
# EPOCH 78/100, Train_Loss: 0.2541, Train_Acc: 0.9084, Validation Loss: 0.3370, Val_Acc: 0.8810
# EPOCH 79/100, Train_Loss: 0.2497, Train_Acc: 0.9100, Validation Loss: 0.3370, Val_Acc: 0.8787
# EPOCH 80/100, Train_Loss: 0.2523, Train_Acc: 0.9088, Validation Loss: 0.3704, Val_Acc: 0.8708
# EPOCH 81/100, Train_Loss: 0.2500, Train_Acc: 0.9109, Validation Loss: 0.3456, Val_Acc: 0.8780
# EPOCH 82/100, Train_Loss: 0.2450, Train_Acc: 0.9121, Validation Loss: 0.3493, Val_Acc: 0.8757
# EPOCH 83/100, Train_Loss: 0.2465, Train_Acc: 0.9114, Validation Loss: 0.3481, Val_Acc: 0.8763
# EPOCH 84/100, Train_Loss: 0.2450, Train_Acc: 0.9115, Validation Loss: 0.3787, Val_Acc: 0.8692
# EPOCH 85/100, Train_Loss: 0.2483, Train_Acc: 0.9122, Validation Loss: 0.3550, Val_Acc: 0.8802
# EPOCH 86/100, Train_Loss: 0.2429, Train_Acc: 0.9116, Validation Loss: 0.3771, Val_Acc: 0.8667
# EPOCH 87/100, Train_Loss: 0.2411, Train_Acc: 0.9123, Validation Loss: 0.3484, Val_Acc: 0.8777
# EPOCH 88/100, Train_Loss: 0.2386, Train_Acc: 0.9142, Validation Loss: 0.3581, Val_Acc: 0.8753
# EPOCH 89/100, Train_Loss: 0.2542, Train_Acc: 0.9103, Validation Loss: 0.3475, Val_Acc: 0.8833
# EPOCH 90/100, Train_Loss: 0.2384, Train_Acc: 0.9145, Validation Loss: 0.3402, Val_Acc: 0.8813
# EPOCH 91/100, Train_Loss: 0.2361, Train_Acc: 0.9151, Validation Loss: 0.3752, Val_Acc: 0.8612
# EPOCH 92/100, Train_Loss: 0.2336, Train_Acc: 0.9168, Validation Loss: 0.3585, Val_Acc: 0.8722
# EPOCH 93/100, Train_Loss: 0.2327, Train_Acc: 0.9165, Validation Loss: 0.3281, Val_Acc: 0.8868
# EPOCH 94/100, Train_Loss: 0.2391, Train_Acc: 0.9146, Validation Loss: 0.3414, Val_Acc: 0.8782
# EPOCH 95/100, Train_Loss: 0.2289, Train_Acc: 0.9156, Validation Loss: 0.3779, Val_Acc: 0.8693
# EPOCH 96/100, Train_Loss: 0.2457, Train_Acc: 0.9129, Validation Loss: 0.3460, Val_Acc: 0.8818
# EPOCH 97/100, Train_Loss: 0.2283, Train_Acc: 0.9164, Validation Loss: 0.3722, Val_Acc: 0.8720
# EPOCH 98/100, Train_Loss: 0.2263, Train_Acc: 0.9189, Validation Loss: 0.3260, Val_Acc: 0.8853
# EPOCH 99/100, Train_Loss: 0.2332, Train_Acc: 0.9177, Validation Loss: 0.3567, Val_Acc: 0.8758
# EPOCH 100/100, Train_Loss: 0.2236, Train_Acc: 0.9204, Validation Loss: 0.3307, Val_Acc: 0.8862

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

# Vẽ Training Loss
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

# Vẽ Validation Loss
ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

# Vẽ Training Accuracy
ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

# Vẽ Validation Accuracy
ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
test_target = []
test_predict = []

# Đặt mô hình ở chế độ đánh giá
model.eval()
with torch.no_grad():
    for X_test, y_test in test_loader:
        X_test = X_test.to(device)
        y_test = y_test.to(device)
        outputs = model(X_test)

        # Lưu lại dự đoán và nhãn thực tế
        test_predict.append(outputs.cpu())
        test_target.append(y_test.cpu())

# Ghép kết quả từ các batch thành một tensor duy nhất
test_predict = torch.cat(test_predict)
test_target = torch.cat(test_target)

# Tính toán độ chính xác
test_acc = (torch.argmax(test_predict, 1) == test_target).sum().item() / len(test_target)

# In kết quả
print('Evaluation on test set:')
print(f'Accuracy: {test_acc:.4f}')
# Out:
# Evaluation on test set:
# Accuracy: 0.8786
