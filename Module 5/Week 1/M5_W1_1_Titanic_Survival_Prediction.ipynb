# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Đọc dữ liệu từ file .csv
dataset_path = '/content/titanic_modified_dataset.csv'
df = pd.read_csv(dataset_path, index_col='PassengerId')

# %%
dataset_arr = df.to_numpy().astype(np.float64)
X, y = dataset_arr[:, :-1], dataset_arr[:, -1]  # Tách X và y từ mảng

# %%
intercept = np.ones((X.shape[0], 1))
X_b = np.concatenate((intercept, X), axis=1)  # Kết hợp cột bias với X

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

# Chia tập `train` và `val`
X_train, X_val, y_train, y_val = train_test_split(X_b, y, test_size=val_size, random_state=random_state, shuffle=is_shuffle)

# Chia tiếp tập `train` thành `train` và `test`
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=test_size, random_state=random_state, shuffle=is_shuffle)

# %%
# Chuẩn hóa dữ liệu
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.transform(X_test[:, 1:])

# %%
# Hàm sigmoid
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
# Hàm Dự Đoán
def predict(X, theta):
    dot_product = np.dot(X, theta)
    y_hat = sigmoid(dot_product)
    return y_hat

# %%
# Hàm Tính Loss (Cross-Entropy)
def compute_loss(y_hat, y):
    y_hat = np.clip(y_hat, 1e-7, 1 - 1e-7)
    return (-y * np.log(y_hat) - (1 - y) * np.log(1 - y_hat)).mean()

# %%
# Hàm tính gradient
def compute_gradient(X, y, y_hat):
    return np.dot(X.T, (y_hat - y)) / y.size

# %%
# Hàm Cập Nhật Trọng Số
def update_theta(theta, gradient, lr):
    return theta - lr * gradient

# %%
# Hàm Tính Độ Chính Xác
def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta).round()
    acc = (y_hat == y).mean()
    return acc

# %%
# Khai Báo Siêu Tham Số và Khởi Tạo theta
lr = 0.01
epochs = 100
batch_size = 16

np.random.seed(random_state)
theta = np.random.uniform(size=X_train.shape[1])

# %%
# Huấn Luyện Mô Hình
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_losses = []
    train_batch_accs = []
    val_batch_losses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i:i + batch_size]
        y_i = y_train[i:i + batch_size]

        # Dự đoán
        y_hat = predict(X_i, theta)

        # Tính loss
        train_loss = compute_loss(y_hat, y_i)

        # Tính gradient
        gradient = compute_gradient(X_i, y_i, y_hat)

        # Cập nhật theta
        theta = update_theta(theta, gradient, lr)

        # Lưu loss của batch hiện tại
        train_batch_losses.append(train_loss)

    # Tính độ chính xác cho tập train và val
    train_acc = compute_accuracy(X_train, y_train, theta)
    val_acc = compute_accuracy(X_val, y_val, theta)

    train_batch_accs.append(train_acc)
    y_val_hat = predict(X_val, theta)
    val_loss = compute_loss(y_val_hat, y_val)
    val_batch_losses.append(val_loss)
    val_batch_accs.append(val_acc)

    # Tính trung bình loss và accuracy cho từng epoch
    train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
    val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    # Lưu loss và accuracy vào danh sách toàn cục
    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    # In ra loss và accuracy cho mỗi epoch
    print(f'\nEPOCH {epoch + 1}: Training loss: {train_batch_loss:.3f} Validation loss: {val_batch_loss:.3f}')
# Out:
# EPOCH 1: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 2: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 3: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 4: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 5: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 6: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 7: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 8: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 9: Training loss: 0.412 Validation loss: 0.520
#
# EPOCH 10: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 11: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 12: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 13: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 14: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 15: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 16: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 17: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 18: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 19: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 20: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 21: Training loss: 0.412 Validation loss: 0.521
#
# EPOCH 22: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 23: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 24: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 25: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 26: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 27: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 28: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 29: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 30: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 31: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 32: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 33: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 34: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 35: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 36: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 37: Training loss: 0.412 Validation loss: 0.522
#
# EPOCH 38: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 39: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 40: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 41: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 42: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 43: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 44: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 45: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 46: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 47: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 48: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 49: Training loss: 0.412 Validation loss: 0.523
#
# EPOCH 50: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 51: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 52: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 53: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 54: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 55: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 56: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 57: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 58: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 59: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 60: Training loss: 0.411 Validation loss: 0.523
#
# EPOCH 61: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 62: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 63: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 64: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 65: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 66: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 67: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 68: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 69: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 70: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 71: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 72: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 73: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 74: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 75: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 76: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 77: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 78: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 79: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 80: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 81: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 82: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 83: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 84: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 85: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 86: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 87: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 88: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 89: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 90: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 91: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 92: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 93: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 94: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 95: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 96: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 97: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 98: Training loss: 0.411 Validation loss: 0.524
#
# EPOCH 99: Training loss: 0.411 Validation loss: 0.525
#
# EPOCH 100: Training loss: 0.411 Validation loss: 0.525

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

# Biểu đồ Training Loss
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

# Biểu đồ Validation Loss
ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

# Biểu đồ Training Accuracy
ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

# Biểu đồ Validation Accuracy
ax[1, 1].plot(val_accs, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)

print('Evaluation on validation and test set:')
print(f'Validation Accuracy: {val_set_acc}')
print(f'Test Accuracy: {test_set_acc}')
# Out:
# Evaluation on validation and test set:
# Validation Accuracy: 0.770949720670391
# Test Accuracy: 0.7865168539325843
