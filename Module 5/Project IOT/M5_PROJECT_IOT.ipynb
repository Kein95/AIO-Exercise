# %%
# !pip install mediapipe==0.10.18
# Out:
# Collecting mediapipe==0.10.18
#   Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (3.8.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.25.5)
# Collecting sounddevice>=0.4.4 (from mediapipe==0.10.18)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.18) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.18) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.18) (1.17.0)
# Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 50.9 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.18 sounddevice-0.5.1

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 46.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label)),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data
            optimizer.zero_grad()
            preds = model(inputs)
            loss = loss_function(preds,labels)
            loss.backward()
            optimizer.step()
            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)
        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset,batch_size=40,shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30,min_delta=0.01)
optimizer = optim.Adam(model.parameters(),lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.2227674126625061, val:0.12627986073493958
# LOSS train 1.608360088788546 valid 1.61589781443278
# Training vs. Validation Loss {'Training': 1.608360088788546, 'Validation': 1.61589781443278} 1
# Training vs. Validation accuracy {'Training': 0.2227674126625061, 'Validation': 0.12627986073493958} 1
# Epoch 1:
# Accuracy train:0.28066733479499817, val:0.22525596618652344
# LOSS train 1.5887212524047265 valid 1.5985275109608967
# Training vs. Validation Loss {'Training': 1.5887212524047265, 'Validation': 1.5985275109608967} 2
# Training vs. Validation accuracy {'Training': 0.28066733479499817, 'Validation': 0.22525596618652344} 2
# Epoch 2:
# Accuracy train:0.3238469064235687, val:0.255972683429718
# LOSS train 1.5675261112359853 valid 1.5822900533676147
# Training vs. Validation Loss {'Training': 1.5675261112359853, 'Validation': 1.5822900533676147} 3
# Training vs. Validation accuracy {'Training': 0.3238469064235687, 'Validation': 0.255972683429718} 3
# Epoch 3:
# Accuracy train:0.3866535723209381, val:0.266211599111557
# LOSS train 1.5461354301525996 valid 1.5655095775922139
# Training vs. Validation Loss {'Training': 1.5461354301525996, 'Validation': 1.5655095775922139} 4
# Training vs. Validation accuracy {'Training': 0.3866535723209381, 'Validation': 0.266211599111557} 4
# Epoch 4:
# Accuracy train:0.4455348253250122, val:0.38225257396698
# LOSS train 1.5052878948358388 valid 1.5248783628145854
# Training vs. Validation Loss {'Training': 1.5052878948358388, 'Validation': 1.5248783628145854} 5
# Training vs. Validation accuracy {'Training': 0.4455348253250122, 'Validation': 0.38225257396698} 5
# Epoch 5:
# Accuracy train:0.48871442675590515, val:0.43344709277153015
# LOSS train 1.4537760065152094 valid 1.470527430375417
# Training vs. Validation Loss {'Training': 1.4537760065152094, 'Validation': 1.470527430375417} 6
# Training vs. Validation accuracy {'Training': 0.48871442675590515, 'Validation': 0.43344709277153015} 6
# Epoch 6:
# Accuracy train:0.5417075753211975, val:0.5221843123435974
# LOSS train 1.3766430295430696 valid 1.3662692705790203
# Training vs. Validation Loss {'Training': 1.3766430295430696, 'Validation': 1.3662692705790203} 7
# Training vs. Validation accuracy {'Training': 0.5417075753211975, 'Validation': 0.5221843123435974} 7
# Epoch 7:
# Accuracy train:0.6094210147857666, val:0.6006826162338257
# LOSS train 1.2492868166703444 valid 1.2242711186408997
# Training vs. Validation Loss {'Training': 1.2492868166703444, 'Validation': 1.2242711186408997} 8
# Training vs. Validation accuracy {'Training': 0.6094210147857666, 'Validation': 0.6006826162338257} 8
# Epoch 8:
# Accuracy train:0.6643768548965454, val:0.6621160507202148
# LOSS train 1.1056060309593494 valid 1.0417928496996562
# Training vs. Validation Loss {'Training': 1.1056060309593494, 'Validation': 1.0417928496996562} 9
# Training vs. Validation accuracy {'Training': 0.6643768548965454, 'Validation': 0.6621160507202148} 9
# Epoch 9:
# Accuracy train:0.7173699736595154, val:0.703071653842926
# LOSS train 0.947446719958232 valid 0.8939890364805857
# Training vs. Validation Loss {'Training': 0.947446719958232, 'Validation': 0.8939890364805857} 10
# Training vs. Validation accuracy {'Training': 0.7173699736595154, 'Validation': 0.703071653842926} 10
# Epoch 10:
# Accuracy train:0.774288535118103, val:0.703071653842926
# LOSS train 0.7957159670499655 valid 0.745063121120135
# Training vs. Validation Loss {'Training': 0.7957159670499655, 'Validation': 0.745063121120135} 11
# Training vs. Validation accuracy {'Training': 0.774288535118103, 'Validation': 0.703071653842926} 11
# Epoch 11:
# Accuracy train:0.8056918382644653, val:0.703071653842926
# LOSS train 0.6878537008395562 valid 0.6443632741769155
# Training vs. Validation Loss {'Training': 0.6878537008395562, 'Validation': 0.6443632741769155} 12
# Training vs. Validation accuracy {'Training': 0.8056918382644653, 'Validation': 0.703071653842926} 12
# Epoch 12:
# Accuracy train:0.8331697583198547, val:0.7986348271369934
# LOSS train 0.5572141328683267 valid 0.5118433355043331
# Training vs. Validation Loss {'Training': 0.5572141328683267, 'Validation': 0.5118433355043331} 13
# Training vs. Validation accuracy {'Training': 0.8331697583198547, 'Validation': 0.7986348271369934} 13
# Epoch 13:
# Accuracy train:0.8724239468574524, val:0.914675772190094
# LOSS train 0.4663667587133554 valid 0.40406547238429386
# Training vs. Validation Loss {'Training': 0.4663667587133554, 'Validation': 0.40406547238429386} 14
# Training vs. Validation accuracy {'Training': 0.8724239468574524, 'Validation': 0.914675772190094} 14
# Epoch 14:
# Accuracy train:0.9018645882606506, val:0.9624573588371277
# LOSS train 0.3818700508429454 valid 0.31006436826040346
# Training vs. Validation Loss {'Training': 0.3818700508429454, 'Validation': 0.31006436826040346} 15
# Training vs. Validation accuracy {'Training': 0.9018645882606506, 'Validation': 0.9624573588371277} 15
# Epoch 15:
# Accuracy train:0.9332678914070129, val:0.9726962447166443
# LOSS train 0.3100106676037495 valid 0.22017463653658828
# Training vs. Validation Loss {'Training': 0.3100106676037495, 'Validation': 0.22017463653658828} 16
# Training vs. Validation accuracy {'Training': 0.9332678914070129, 'Validation': 0.9726962447166443} 16
# Epoch 16:
# Accuracy train:0.9528949856758118, val:0.9863481521606445
# LOSS train 0.23764249567802137 valid 0.14477696533625325
# Training vs. Validation Loss {'Training': 0.23764249567802137, 'Validation': 0.14477696533625325} 17
# Training vs. Validation accuracy {'Training': 0.9528949856758118, 'Validation': 0.9863481521606445} 17
# Epoch 17:
# Accuracy train:0.96467125415802, val:0.9829351305961609
# LOSS train 0.2017561011016369 valid 0.09608376778972645
# Training vs. Validation Loss {'Training': 0.2017561011016369, 'Validation': 0.09608376778972645} 18
# Training vs. Validation accuracy {'Training': 0.96467125415802, 'Validation': 0.9829351305961609} 18
# Epoch 18:
# Accuracy train:0.9725220799446106, val:0.9863481521606445
# LOSS train 0.15894577881464592 valid 0.05407202139031142
# Training vs. Validation Loss {'Training': 0.15894577881464592, 'Validation': 0.05407202139031142} 19
# Training vs. Validation accuracy {'Training': 0.9725220799446106, 'Validation': 0.9863481521606445} 19
# Epoch 19:
# Accuracy train:0.981354296207428, val:0.9931740760803223
# LOSS train 0.14137991460470054 valid 0.045113697492827974
# Training vs. Validation Loss {'Training': 0.14137991460470054, 'Validation': 0.045113697492827974} 20
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9931740760803223} 20
# Epoch 20:
# Accuracy train:0.983316957950592, val:0.9829351305961609
# LOSS train 0.11209554726687762 valid 0.035982403360928096
# Training vs. Validation Loss {'Training': 0.11209554726687762, 'Validation': 0.035982403360928096} 21
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9829351305961609} 21
# Epoch 21:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.10708465097615352 valid 0.027396827839159716
# Training vs. Validation Loss {'Training': 0.10708465097615352, 'Validation': 0.027396827839159716} 22
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 22
# Epoch 22:
# Accuracy train:0.98233562707901, val:0.9829351305961609
# LOSS train 0.10064868041529106 valid 0.04139980370140014
# Training vs. Validation Loss {'Training': 0.10064868041529106, 'Validation': 0.04139980370140014} 23
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9829351305961609} 23
# Epoch 23:
# Accuracy train:0.9774288535118103, val:0.9931740760803223
# LOSS train 0.0901444462629465 valid 0.0196713072170193
# Training vs. Validation Loss {'Training': 0.0901444462629465, 'Validation': 0.0196713072170193} 24
# Training vs. Validation accuracy {'Training': 0.9774288535118103, 'Validation': 0.9931740760803223} 24
# Epoch 24:
# Accuracy train:0.9852796792984009, val:0.9829351305961609
# LOSS train 0.08693219800121509 valid 0.02781160140875727
# Training vs. Validation Loss {'Training': 0.08693219800121509, 'Validation': 0.02781160140875727} 25
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9829351305961609} 25
# Epoch 25:
# Accuracy train:0.9793915748596191, val:0.9965870380401611
# LOSS train 0.0824917693837331 valid 0.0193456312311658
# Training vs. Validation Loss {'Training': 0.0824917693837331, 'Validation': 0.0193456312311658} 26
# Training vs. Validation accuracy {'Training': 0.9793915748596191, 'Validation': 0.9965870380401611} 26
# Epoch 26:
# Accuracy train:0.98233562707901, val:0.9829351305961609
# LOSS train 0.07954700642193739 valid 0.03214305285655428
# Training vs. Validation Loss {'Training': 0.07954700642193739, 'Validation': 0.03214305285655428} 27
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9829351305961609} 27
# Epoch 27:
# Accuracy train:0.9852796792984009, val:0.9965870380401611
# LOSS train 0.06412622060340184 valid 0.015472461978788488
# Training vs. Validation Loss {'Training': 0.06412622060340184, 'Validation': 0.015472461978788488} 28
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9965870380401611} 28
# Epoch 28:
# Accuracy train:0.9842983484268188, val:0.9931740760803223
# LOSS train 0.06347829769723691 valid 0.017032110908379156
# Training vs. Validation Loss {'Training': 0.06347829769723691, 'Validation': 0.017032110908379156} 29
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9931740760803223} 29
# Epoch 29:
# Accuracy train:0.98233562707901, val:0.9897611141204834
# LOSS train 0.09130247266819844 valid 0.019676570573210483
# Training vs. Validation Loss {'Training': 0.09130247266819844, 'Validation': 0.019676570573210483} 30
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9897611141204834} 30
# Epoch 30:
# Accuracy train:0.9852796792984009, val:0.9897611141204834
# LOSS train 0.07046278587614115 valid 0.01932994061159358
# Training vs. Validation Loss {'Training': 0.07046278587614115, 'Validation': 0.01932994061159358} 31
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9897611141204834} 31
# Epoch 31:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.05544909372782478 valid 0.013657747355561392
# Training vs. Validation Loss {'Training': 0.05544909372782478, 'Validation': 0.013657747355561392} 32
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 32
# Epoch 32:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.06245860940991686 valid 0.014031190758032608
# Training vs. Validation Loss {'Training': 0.06245860940991686, 'Validation': 0.014031190758032608} 33
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 33
# Epoch 33:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.06059058683996017 valid 0.013287740444260029
# Training vs. Validation Loss {'Training': 0.06059058683996017, 'Validation': 0.013287740444260029} 34
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 34
# Epoch 34:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.0619786697296569 valid 0.015617794808349572
# Training vs. Validation Loss {'Training': 0.0619786697296569, 'Validation': 0.015617794808349572} 35
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 35
# Epoch 35:
# Accuracy train:0.9803729057312012, val:1.0
# LOSS train 0.04920582627304471 valid 0.008525027100404259
# Training vs. Validation Loss {'Training': 0.04920582627304471, 'Validation': 0.008525027100404259} 36
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 1.0} 36
# Epoch 36:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.058219380264815226 valid 0.01230650230051348
# Training vs. Validation Loss {'Training': 0.058219380264815226, 'Validation': 0.01230650230051348} 37
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 37
# Epoch 37:
# Accuracy train:0.9882237315177917, val:1.0
# LOSS train 0.05769427192325775 valid 0.009008356068685922
# Training vs. Validation Loss {'Training': 0.05769427192325775, 'Validation': 0.009008356068685922} 38
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 1.0} 38
# Epoch 38:
# Accuracy train:0.9872424006462097, val:0.9965870380401611
# LOSS train 0.05276904462908323 valid 0.013122300846589496
# Training vs. Validation Loss {'Training': 0.05276904462908323, 'Validation': 0.013122300846589496} 39
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9965870380401611} 39
# Epoch 39:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.05065061237949591 valid 0.014216839255823288
# Training vs. Validation Loss {'Training': 0.05065061237949591, 'Validation': 0.014216839255823288} 40
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 40
# Epoch 40:
# Accuracy train:0.9842983484268188, val:0.9897611141204834
# LOSS train 0.058396356825072035 valid 0.01968406487928102
# Training vs. Validation Loss {'Training': 0.058396356825072035, 'Validation': 0.01968406487928102} 41
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9897611141204834} 41
# Epoch 41:
# Accuracy train:0.9852796792984009, val:0.9965870380401611
# LOSS train 0.055276618661502235 valid 0.009347688825679748
# Training vs. Validation Loss {'Training': 0.055276618661502235, 'Validation': 0.009347688825679748} 42
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9965870380401611} 42
# Epoch 42:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.04767136639342285 valid 0.014274042421069074
# Training vs. Validation Loss {'Training': 0.04767136639342285, 'Validation': 0.014274042421069074} 43
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 43
# Epoch 43:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.04476736462675035 valid 0.006590052285901038
# Training vs. Validation Loss {'Training': 0.04476736462675035, 'Validation': 0.006590052285901038} 44
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 44
# Epoch 44:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.0415057187111905 valid 0.007549038413344533
# Training vs. Validation Loss {'Training': 0.0415057187111905, 'Validation': 0.007549038413344533} 45
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 45
# Epoch 45:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.035771154100075364 valid 0.010680733701216619
# Training vs. Validation Loss {'Training': 0.035771154100075364, 'Validation': 0.010680733701216619} 46
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 46
# Epoch 46:
# Accuracy train:0.9842983484268188, val:0.9897611141204834
# LOSS train 0.048989519387340315 valid 0.02183163338668237
# Training vs. Validation Loss {'Training': 0.048989519387340315, 'Validation': 0.02183163338668237} 47
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9897611141204834} 47
# Epoch 47:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.03334474151667494 valid 0.010837641806877704
# Training vs. Validation Loss {'Training': 0.03334474151667494, 'Validation': 0.010837641806877704} 48
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 48
# Epoch 48:
# Accuracy train:0.9842983484268188, val:0.9965870380401611
# LOSS train 0.05021472622712071 valid 0.010767286834986104
# Training vs. Validation Loss {'Training': 0.05021472622712071, 'Validation': 0.010767286834986104} 49
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9965870380401611} 49
# Epoch 49:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.03828075071438574 valid 0.009493734733950987
# Training vs. Validation Loss {'Training': 0.03828075071438574, 'Validation': 0.009493734733950987} 50
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 50
# Epoch 50:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.04726843304860477 valid 0.013164141887197426
# Training vs. Validation Loss {'Training': 0.04726843304860477, 'Validation': 0.013164141887197426} 51
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 51
# Epoch 51:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.029041006767119352 valid 0.010321271993234404
# Training vs. Validation Loss {'Training': 0.029041006767119352, 'Validation': 0.010321271993234404} 52
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 52
# Epoch 52:
# Accuracy train:0.9892051219940186, val:1.0
# LOSS train 0.033494493494240135 valid 0.008000872153691793
# Training vs. Validation Loss {'Training': 0.033494493494240135, 'Validation': 0.008000872153691793} 53
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 1.0} 53
# Epoch 53:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.058667088518492304 valid 0.014679275832046793
# Training vs. Validation Loss {'Training': 0.058667088518492304, 'Validation': 0.014679275832046793} 54
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 54
# Epoch 54:
# Accuracy train:0.9892051219940186, val:1.0
# LOSS train 0.032281200849236205 valid 0.007721461649756141
# Training vs. Validation Loss {'Training': 0.032281200849236205, 'Validation': 0.007721461649756141} 55
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 1.0} 55
# Epoch 55:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.037773415267180935 valid 0.009186105734443117
# Training vs. Validation Loss {'Training': 0.037773415267180935, 'Validation': 0.009186105734443117} 56
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 56
# Epoch 56:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.03105460420752374 valid 0.008641228225921319
# Training vs. Validation Loss {'Training': 0.03105460420752374, 'Validation': 0.008641228225921319} 57
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 57
# Epoch 57:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.030452176973295327 valid 0.017564547905446187
# Training vs. Validation Loss {'Training': 0.030452176973295327, 'Validation': 0.017564547905446187} 58
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 58
# Epoch 58:
# Accuracy train:0.9862610697746277, val:0.9965870380401611
# LOSS train 0.04813348492070173 valid 0.009740771950115837
# Training vs. Validation Loss {'Training': 0.04813348492070173, 'Validation': 0.009740771950115837} 59
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9965870380401611} 59
# Epoch 59:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.02940608369401441 valid 0.01486706332252652
# Training vs. Validation Loss {'Training': 0.02940608369401441, 'Validation': 0.01486706332252652} 60
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 60
# Epoch 60:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.04200252856557759 valid 0.007551761147927512
# Training vs. Validation Loss {'Training': 0.04200252856557759, 'Validation': 0.007551761147927512} 61
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 61
# Epoch 61:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.03355782749489523 valid 0.007337663569614961
# Training vs. Validation Loss {'Training': 0.03355782749489523, 'Validation': 0.007337663569614961} 62
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 62
# Epoch 62:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.02608123673305202 valid 0.009613908864290957
# Training vs. Validation Loss {'Training': 0.02608123673305202, 'Validation': 0.009613908864290957} 63
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 63
# Epoch 63:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.030749358380070098 valid 0.008523126621942842
# Training vs. Validation Loss {'Training': 0.030749358380070098, 'Validation': 0.008523126621942842} 64
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 64
# Epoch 64:
# Accuracy train:0.9921491742134094, val:1.0
# LOSS train 0.03067432797084061 valid 0.007307112937345058
# Training vs. Validation Loss {'Training': 0.03067432797084061, 'Validation': 0.007307112937345058} 65
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 1.0} 65
# Epoch 65:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.034132895265849166 valid 0.007707124055741588
# Training vs. Validation Loss {'Training': 0.034132895265849166, 'Validation': 0.007707124055741588} 66
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 66
# Epoch 66:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.025735778134101286 valid 0.007971426199219422
# Training vs. Validation Loss {'Training': 0.025735778134101286, 'Validation': 0.007971426199219422} 67
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 67
# Epoch 67:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.028785407507362273 valid 0.00864876350654716
# Training vs. Validation Loss {'Training': 0.028785407507362273, 'Validation': 0.00864876350654716} 68
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 68
# Epoch 68:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.04828711376131441 valid 0.010033442467223116
# Training vs. Validation Loss {'Training': 0.04828711376131441, 'Validation': 0.010033442467223116} 69
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 69
# Epoch 69:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.024291682513788916 valid 0.009245945122681102
# Training vs. Validation Loss {'Training': 0.024291682513788916, 'Validation': 0.009245945122681102} 70
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 70
# Epoch 70:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.03910684350054138 valid 0.007807956674848053
# Training vs. Validation Loss {'Training': 0.03910684350054138, 'Validation': 0.007807956674848053} 71
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 71
# Epoch 71:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.02729030889727605 valid 0.007869140665510107
# Training vs. Validation Loss {'Training': 0.02729030889727605, 'Validation': 0.007869140665510107} 72
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 72
# Epoch 72:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.027625929403047148 valid 0.009572926188260075
# Training vs. Validation Loss {'Training': 0.027625929403047148, 'Validation': 0.009572926188260075} 73
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 73
# Epoch 73:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.027063567030171935 valid 0.009521052763223755
# Training vs. Validation Loss {'Training': 0.027063567030171935, 'Validation': 0.009521052763223755} 74
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 74
# Epoch 74:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.028048683289223567 valid 0.009118406137379983
# Training vs. Validation Loss {'Training': 0.028048683289223567, 'Validation': 0.009118406137379983} 75
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 75
# Epoch 75:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.02173559839138761 valid 0.010569526178111724
# Training vs. Validation Loss {'Training': 0.02173559839138761, 'Validation': 0.010569526178111724} 76
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 76
# Epoch 76:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.024504884916286055 valid 0.009094157566551075
# Training vs. Validation Loss {'Training': 0.024504884916286055, 'Validation': 0.009094157566551075} 77
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 77
# Epoch 77:
# Accuracy train:0.9950932264328003, val:1.0
# LOSS train 0.02235039710873165 valid 0.007965471878454386
# Training vs. Validation Loss {'Training': 0.02235039710873165, 'Validation': 0.007965471878454386} 78
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 1.0} 78
# Epoch 78:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.026906668732408434 valid 0.007816932555821646
# Training vs. Validation Loss {'Training': 0.026906668732408434, 'Validation': 0.007816932555821646} 79
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 79
# Epoch 79:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.030037634365726262 valid 0.008410649124622674
# Training vs. Validation Loss {'Training': 0.030037634365726262, 'Validation': 0.008410649124622674} 80
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 80
# Epoch 80:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.018592865824197922 valid 0.012349300073083214
# Training vs. Validation Loss {'Training': 0.018592865824197922, 'Validation': 0.012349300073083214} 81
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 81
# Epoch 81:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.022396451565257918 valid 0.011363305197316246
# Training vs. Validation Loss {'Training': 0.022396451565257918, 'Validation': 0.011363305197316246} 82
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 82
# Epoch 82:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.0258380654357517 valid 0.01441266572423198
# Training vs. Validation Loss {'Training': 0.0258380654357517, 'Validation': 0.01441266572423198} 83
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 83
# Epoch 83:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.01452619828677808 valid 0.01374088432244965
# Training vs. Validation Loss {'Training': 0.01452619828677808, 'Validation': 0.01374088432244965} 84
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 84
# Epoch 84:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.01688698833459057 valid 0.01826171858806447
# Training vs. Validation Loss {'Training': 0.01688698833459057, 'Validation': 0.01826171858806447} 85
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 85
# Epoch 85:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.01966949007832087 valid 0.01183717802045218
# Training vs. Validation Loss {'Training': 0.01966949007832087, 'Validation': 0.01183717802045218} 86
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 86
# Epoch 86:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.013284141927635154 valid 0.0179782907016867
# Training vs. Validation Loss {'Training': 0.013284141927635154, 'Validation': 0.0179782907016867} 87
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 87
# Epoch 87:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.04384885366128471 valid 0.00816678159537787
# Training vs. Validation Loss {'Training': 0.04384885366128471, 'Validation': 0.00816678159537787} 88
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 88
# Epoch 88:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.02238521724043844 valid 0.008366820755801049
# Training vs. Validation Loss {'Training': 0.02238521724043844, 'Validation': 0.008366820755801049} 89
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 89
# Epoch 89:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.03552577127881635 valid 0.013149184931990021
# Training vs. Validation Loss {'Training': 0.03552577127881635, 'Validation': 0.013149184931990021} 90
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 90
# Epoch 90:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.017065964036961444 valid 0.007306450410169418
# Training vs. Validation Loss {'Training': 0.017065964036961444, 'Validation': 0.007306450410169418} 91
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 91
# Epoch 91:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.02691816686777971 valid 0.010146324576415585
# Training vs. Validation Loss {'Training': 0.02691816686777971, 'Validation': 0.010146324576415585} 92
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 92
# Epoch 92:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.027754316822840616 valid 0.015123526019124256
# Training vs. Validation Loss {'Training': 0.027754316822840616, 'Validation': 0.015123526019124256} 93
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 93
# Epoch 93:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.022872120762118496 valid 0.012988928707045488
# Training vs. Validation Loss {'Training': 0.022872120762118496, 'Validation': 0.012988928707045488} 94
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 94
# Epoch 94:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.03880366490473254 valid 0.010589922605352816
# Training vs. Validation Loss {'Training': 0.03880366490473254, 'Validation': 0.010589922605352816} 95
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 95
# Epoch 95:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.018258478564138595 valid 0.012951886680847716
# Training vs. Validation Loss {'Training': 0.018258478564138595, 'Validation': 0.012951886680847716} 96
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 96
# Epoch 96:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.017998772530028455 valid 0.012244742435541411
# Training vs. Validation Loss {'Training': 0.017998772530028455, 'Validation': 0.012244742435541411} 97
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 97
# Epoch 97:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.028772857232699886 valid 0.010973642741798054
# Training vs. Validation Loss {'Training': 0.028772857232699886, 'Validation': 0.010973642741798054} 98
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 98
# Epoch 98:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.01963610188641514 valid 0.009743570972167012
# Training vs. Validation Loss {'Training': 0.01963610188641514, 'Validation': 0.009743570972167012} 99
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 99
# Epoch 99:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.012137161245426306 valid 0.01195408251101071
# Training vs. Validation Loss {'Training': 0.012137161245426306, 'Validation': 0.01195408251101071} 100
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 100
# Epoch 100:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.018882352366255455 valid 0.013830128880404876
# Training vs. Validation Loss {'Training': 0.018882352366255455, 'Validation': 0.013830128880404876} 101
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 101
# Epoch 101:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.014720973229626767 valid 0.01665048352019009
# Training vs. Validation Loss {'Training': 0.014720973229626767, 'Validation': 0.01665048352019009} 102
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 102
# Epoch 102:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.018491506849666342 valid 0.013356950948567222
# Training vs. Validation Loss {'Training': 0.018491506849666342, 'Validation': 0.013356950948567222} 103
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 103
# Epoch 103:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.020114325269017942 valid 0.01565567419030837
# Training vs. Validation Loss {'Training': 0.020114325269017942, 'Validation': 0.01565567419030837} 104
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 104
# Epoch 104:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.018105300917970732 valid 0.025650249324788394
# Training vs. Validation Loss {'Training': 0.018105300917970732, 'Validation': 0.025650249324788394} 105
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 105
# Epoch 105:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.011237393193788683 valid 0.010776350025234175
# Training vs. Validation Loss {'Training': 0.011237393193788683, 'Validation': 0.010776350025234175} 106
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 106
# Epoch 106:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.012270784287606008 valid 0.013645479288148485
# Training vs. Validation Loss {'Training': 0.012270784287606008, 'Validation': 0.013645479288148485} 107
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 107
# Epoch 107:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.016239868481464397 valid 0.009952995014041713
# Training vs. Validation Loss {'Training': 0.016239868481464397, 'Validation': 0.009952995014041713} 108
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 108
# Epoch 108:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.012508481590954874 valid 0.015978654146654964
# Training vs. Validation Loss {'Training': 0.012508481590954874, 'Validation': 0.015978654146654964} 109
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 109
# Epoch 109:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.01800800515159678 valid 0.013669547252542694
# Training vs. Validation Loss {'Training': 0.01800800515159678, 'Validation': 0.013669547252542694} 110
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 110
# Epoch 110:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.015499910812090652 valid 0.012444635410095847
# Training vs. Validation Loss {'Training': 0.015499910812090652, 'Validation': 0.012444635410095847} 111
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 111
# Epoch 111:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.01136332336178524 valid 0.017990626566245282
# Training vs. Validation Loss {'Training': 0.01136332336178524, 'Validation': 0.017990626566245282} 112
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 112
# Epoch 112:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.028766174549953297 valid 0.014599746098487762
# Training vs. Validation Loss {'Training': 0.028766174549953297, 'Validation': 0.014599746098487762} 113
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 113
# Epoch 113:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.010538452526536556 valid 0.009287384971116808
# Training vs. Validation Loss {'Training': 0.010538452526536556, 'Validation': 0.009287384971116808} 114
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 114
# Epoch 114:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.012872708699433133 valid 0.023867971541297568
# Training vs. Validation Loss {'Training': 0.012872708699433133, 'Validation': 0.023867971541297568} 115
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 115
# Epoch 115:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.010201641051725555 valid 0.020619625931146857
# Training vs. Validation Loss {'Training': 0.010201641051725555, 'Validation': 0.020619625931146857} 116
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 116
# Epoch 116:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.010966817785699207 valid 0.020561778858270447
# Training vs. Validation Loss {'Training': 0.010966817785699207, 'Validation': 0.020561778858270447} 117
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 117
# Epoch 117:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.011158230757036317 valid 0.02292722923383887
# Training vs. Validation Loss {'Training': 0.011158230757036317, 'Validation': 0.02292722923383887} 118
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 118
# Epoch 118:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.017083715308287468 valid 0.008484974699589051
# Training vs. Validation Loss {'Training': 0.017083715308287468, 'Validation': 0.008484974699589051} 119
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 119
# Epoch 119:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.017699824751336843 valid 0.017713465941398
# Training vs. Validation Loss {'Training': 0.017699824751336843, 'Validation': 0.017713465941398} 120
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 120
# Epoch 120:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.016944005881669 valid 0.011573520073776914
# Training vs. Validation Loss {'Training': 0.016944005881669, 'Validation': 0.011573520073776914} 121
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 121
# Epoch 121:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.007190642779907928 valid 0.01362059260048909
# Training vs. Validation Loss {'Training': 0.007190642779907928, 'Validation': 0.01362059260048909} 122
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 122
# Epoch 122:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.01486355466029356 valid 0.01233982087306155
# Training vs. Validation Loss {'Training': 0.01486355466029356, 'Validation': 0.01233982087306155} 123
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 123
# Epoch 123:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.026381722575304314 valid 0.011596182466263372
# Training vs. Validation Loss {'Training': 0.026381722575304314, 'Validation': 0.011596182466263372} 124
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 124
# Epoch 124:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.019215529401732896 valid 0.01646985105878211
# Training vs. Validation Loss {'Training': 0.019215529401732896, 'Validation': 0.01646985105878211} 125
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 125
# Epoch 125:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.013383459313235316 valid 0.025552767194653825
# Training vs. Validation Loss {'Training': 0.013383459313235316, 'Validation': 0.025552767194653825} 126
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 126
# Epoch 126:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.02435327283008239 valid 0.0139708965454588
# Training vs. Validation Loss {'Training': 0.02435327283008239, 'Validation': 0.0139708965454588} 127
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 127
# Epoch 127:
# Accuracy train:0.999018669128418, val:0.9965870380401611
# LOSS train 0.011399746973228712 valid 0.012570909457518079
# Training vs. Validation Loss {'Training': 0.011399746973228712, 'Validation': 0.012570909457518079} 128
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9965870380401611} 128
# Epoch 128:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.013268180247485781 valid 0.018419105034467975
# Training vs. Validation Loss {'Training': 0.013268180247485781, 'Validation': 0.018419105034467975} 129
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 129
# Epoch 129:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.011116623941164177 valid 0.025029027132144204
# Training vs. Validation Loss {'Training': 0.011116623941164177, 'Validation': 0.025029027132144204} 130
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 130
# Epoch 130:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.021199255609714713 valid 0.017401725695975756
# Training vs. Validation Loss {'Training': 0.021199255609714713, 'Validation': 0.017401725695975756} 131
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 131
# Epoch 131:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.01738529860561427 valid 0.021172729342187797
# Training vs. Validation Loss {'Training': 0.01738529860561427, 'Validation': 0.021172729342187797} 132
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 132
# Epoch 132:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.008540669433736743 valid 0.017038157373415668
# Training vs. Validation Loss {'Training': 0.008540669433736743, 'Validation': 0.017038157373415668} 133
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 133
# Epoch 133:
# Accuracy train:0.9980372786521912, val:0.9863481521606445
# LOSS train 0.013826899253987134 valid 0.027875017517146716
# Training vs. Validation Loss {'Training': 0.013826899253987134, 'Validation': 0.027875017517146716} 134
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9863481521606445} 134
# Epoch 134:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.023749257917538322 valid 0.028227569475196407
# Training vs. Validation Loss {'Training': 0.023749257917538322, 'Validation': 0.028227569475196407} 135
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 135
# Epoch 135:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.020443868213288415 valid 0.03228520244527999
# Training vs. Validation Loss {'Training': 0.020443868213288415, 'Validation': 0.03228520244527999} 136
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 136
# Epoch 136:
# Accuracy train:0.9950932264328003, val:0.9829351305961609
# LOSS train 0.015307597439879408 valid 0.03211745114572295
# Training vs. Validation Loss {'Training': 0.015307597439879408, 'Validation': 0.03211745114572295} 137
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9829351305961609} 137
# Epoch 137:
# Accuracy train:0.9950932264328003, val:0.9863481521606445
# LOSS train 0.015404915683365498 valid 0.04392180041295054
# Training vs. Validation Loss {'Training': 0.015404915683365498, 'Validation': 0.04392180041295054} 138
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9863481521606445} 138
# Epoch 138:
# Accuracy train:0.999018669128418, val:0.9829351305961609
# LOSS train 0.008277751418063417 valid 0.035120648180959314
# Training vs. Validation Loss {'Training': 0.008277751418063417, 'Validation': 0.035120648180959314} 139
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9829351305961609} 139
# Epoch 139:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.008546193866865136 valid 0.032442676281903005
# Training vs. Validation Loss {'Training': 0.008546193866865136, 'Validation': 0.032442676281903005} 140
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 140
# Epoch 140:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.004919957217330543 valid 0.0317432620392708
# Training vs. Validation Loss {'Training': 0.004919957217330543, 'Validation': 0.0317432620392708} 141
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 141
# Epoch 141:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.005011991561891941 valid 0.023782197503588048
# Training vs. Validation Loss {'Training': 0.005011991561891941, 'Validation': 0.023782197503588048} 142
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 142
# Epoch 142:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.006700702679294269 valid 0.026385126786095725
# Training vs. Validation Loss {'Training': 0.006700702679294269, 'Validation': 0.026385126786095725} 143
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 143
# Epoch 143:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.004493391528600254 valid 0.03044930523867606
# Training vs. Validation Loss {'Training': 0.004493391528600254, 'Validation': 0.03044930523867606} 144
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 144
# Epoch 144:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.013409410107459944 valid 0.02340585004598002
# Training vs. Validation Loss {'Training': 0.013409410107459944, 'Validation': 0.02340585004598002} 145
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 145
# stopping at epoch 144, minimum: 0.006590052285901038
# tensor(0.9932)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))
test_loader = torch.utils.data.DataLoader(testset,batch_size=20,shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network(test_input)
    acc_test.update(preds, test_label)
print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9724409580230713
# ========================================================================
